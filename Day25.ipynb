# %% [markdown]
# <a href="https://colab.research.google.com/github/Aashima593/Training-TR-103-Report/blob/main/Day25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #K-Means

# %% [markdown]
# <img src="data:image/png;base64,..." width=700px height=300px>
#
#
#
# <img src="https://stanford.edu/~cpiech/cs221/img/kmeansViz.png" width=600px>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dhruvalpatel30/driver-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'driver-dataset' dataset.
# Path to dataset files: /kaggle/input/driver-dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('driver-data.csv')
df
# Out:
#               id  mean_dist_day  mean_over_speed_perc
# 0     3423311935          71.24                    28
# 1     3423313212          52.53                    25
# 2     3423313724          64.54                    27
# 3     3423311373          55.69                    22
# 4     3423310999          54.58                    25
# ...          ...            ...                   ...
# 3995  3423310685         160.04                    10
# 3996  3423312600         176.17                     5
# 3997  3423312921         170.91                    12
# 3998  3423313630         176.14                     5
# 3999  3423311533         168.03                     9
#
# [4000 rows x 3 columns]

# %%
X = df.iloc[:, 1:]
X
# Out:
#       mean_dist_day  mean_over_speed_perc
# 0             71.24                    28
# 1             52.53                    25
# 2             64.54                    27
# 3             55.69                    22
# 4             54.58                    25
# ...             ...                   ...
# 3995         160.04                    10
# 3996         176.17                     5
# 3997         170.91                    12
# 3998         176.14                     5
# 3999         168.03                     9
#
# [4000 rows x 2 columns]

# %%
plt.xlabel('mean_dist_day')
plt.ylabel('mean_over_speed_perc')
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=df['id'])
plt.show()

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, init='k-means++')

# %%
model = kmeans.fit(X)

# %%
model.cluster_centers_
# Out:
# array([[ 50.04763437,   8.82875   ],
#        [180.017075  ,  18.29      ]])

# %%
labels = model.labels_
labels
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
df['Cluster_labels'] = labels
df
# Out:
#               id  mean_dist_day  mean_over_speed_perc  Cluster_labels
# 0     3423311935          71.24                    28               0
# 1     3423313212          52.53                    25               0
# 2     3423313724          64.54                    27               0
# 3     3423311373          55.69                    22               0
# 4     3423310999          54.58                    25               0
# ...          ...            ...                   ...             ...
# 3995  3423310685         160.04                    10               1
# 3996  3423312600         176.17                     5               1
# 3997  3423312921         170.91                    12               1
# 3998  3423313630         176.14                     5               1
# 3999  3423311533         168.03                     9               1
#
# [4000 rows x 4 columns]

# %%
plt.xlabel('mean_dist_day')
plt.ylabel('mean_over_speed_perc')
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=df['Cluster_labels'])
plt.show()
